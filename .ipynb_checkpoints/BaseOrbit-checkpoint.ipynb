# %%
from astropy import units as u
from astropy.time import Time

import numpy as np

from poliastro import iod
from poliastro.bodies import Earth, Moon
from poliastro.frames import Planes
from poliastro.ephem import Ephem
from poliastro.maneuver import Maneuver
from poliastro.twobody import Orbit
from poliastro.plotting.static import StaticOrbitPlotter as OrbitPlotter
from poliastro.util import time_range
from poliastro.spacecraft import Spacecraft
# More info: https://plotly.com/python/renderers/
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
from astropy.coordinates import solar_system_ephemeris

# Set up time frame
epoch = Time("2024-05-01 13:05:50", scale = "tdb")

# Basic orbit set up
plotter = OrbitPlotter(plane=Planes.EARTH_ECLIPTIC)
plotter.plot_body_orbit(Earth, epoch, label = "Earth")
plotter.plot_body_orbit(Moon, epoch, label = "Moon")

# Basic satellite object setup
satellite = Ephem.from_horizons(
    attractor = Earth,
    plane = Planes.EARTH_ECLIPTIC,
    id_type = "majorbody",
) 
satellite

# plot satellite
plotter.plot_ephem(satellite, epoch, label = "Sample Satellite", color = "green")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 26
#      24 plotter = OrbitPlotter(plane=Planes.EARTH_ECLIPTIC)
#      25 plotter.plot_body_orbit(Earth, epoch, label = "Earth")
# ---> 26 plotter.plot_body_orbit(Moon, epoch, label = "Moon")
#      28 # Basic satellite object setup
#      29 satellite = Ephem.from_horizons(
#      30     attractor = Earth,
#      31     plane = Planes.EARTH_ECLIPTIC,
#      32     id_type = "majorbody",
#      33 )
#
# File c:\Users\alexa\BrownCS\engn1760\GLASS-OrbitSim\.venv\lib\site-packages\poliastro\plotting\static.py:313, in StaticOrbitPlotter.plot_body_orbit(self, body, epoch, label, color, trail)
#     310 if self._frame is None:
#     311     self.set_body_frame(body, epoch)
# --> 313 lines = self._plot_body_orbit(
#     314     body, epoch, label=label, color=color, trail=trail
#     315 )
#     317 # Set legend using label from last added trajectory
#     318 self._set_legend(self._trajectories[-1].label, *lines)
#
# File c:\Users\alexa\BrownCS\engn1760\GLASS-OrbitSim\.venv\lib\site-packages\poliastro\plotting\_base.py:263, in BaseOrbitPlotter._plot_body_orbit(self, body, epoch, label, color, trail)
#     260 if color is None:
#     261     color = BODY_COLORS.get(body.name)
# --> 263 self.set_attractor(body.parent)
#     265 # Get approximate, mean value for the period
#     266 period = get_mean_elements(body, epoch).period
#
# File c:\Users\alexa\BrownCS\engn1760\GLASS-OrbitSim\.venv\lib\site-packages\poliastro\plotting\_base.py:62, in BaseOrbitPlotter.set_attractor(self, attractor)
#      53 def set_attractor(self, attractor):
#      54     """Sets plotting attractor.
#      55
#      56     Parameters
#    (...)
#      60
#      61     """
# ---> 62     self._set_attractor(attractor)
#
# File c:\Users\alexa\BrownCS\engn1760\GLASS-OrbitSim\.venv\lib\site-packages\poliastro\plotting\_base.py:49, in BaseOrbitPlotter._set_attractor(self, attractor)
#      47     self._attractor = attractor
#      48 elif attractor is not self._attractor:
# ---> 49     raise NotImplementedError(
#      50         f"Attractor has already been set to {self._attractor.name}"
#      51     )
#
# NotImplementedError: Attractor has already been set to Sun
